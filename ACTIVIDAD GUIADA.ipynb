# %% [markdown]
# # ASTRIFÍSICA EXTRAGALÁCTICA

# %% [markdown]
# ## ACTIVIDAD GUIADA - CALCULO DE DISTANCIAS ENTRE GALAXIAS: LAS CEFÉIDAS

# %% [markdown]
# ### Ejercicio 1. Representa la curva de luz de cada estrella Cefeida. Para ello puedes usar cualquier tipo de software, desde Hoja de Cálculo hasta programas tipo Gnuplot, TopCat o Period04. Debes obtener una curva parecida a la que se muestra en la Figura 4 para cada estrella. Recuerda que las magnitudes se miden de forma inversiva, es decir, a mayor brillo, menor magnitud.

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

#Se obtienen y grafican las curvas de luz de las estrellas ceféidas
for starfile in os.listdir('./dataHST'):
    time = []
    magnitude = []
    
    for line in open('./dataHST/'+starfile, 'r'):
        lines = [i for i in line.split()]
        time.append(float(lines[0]))
        magnitude.append(float(lines[1]))
        
    plt.figure(figsize=(10,5))
    plt.title(starfile[0:len(starfile)-4])
    plt.xlabel('Tiempo (dias)')
    plt.ylabel('Magnitud aparente')
    plt.yticks(np.arange(round(min(magnitude),1), round(max(magnitude),1), step=0.1))
    plt.gca().invert_yaxis()
    plt.plot(time, magnitude, marker = 'o', c = 'g')    
    plt.savefig(starfile[0:len(starfile)-4]+'.png')
    plt.show()

# %% [markdown]
# ### 4.	Calcula el diagrama Periodo-Luminosidad para las estrellas Cefeidas de M31 a partir de las columnas Icmag y P de la tabla TopCat (o Aladin). Si es necesario, utiliza la función copiar para editor de textos/copiar para Excel en la propia tabla. Compara tus resultados con el diagrama mostrado en el artículo de Joshi et al. (2003) (ver Figura 11), el resultado obtenido debería de ser muy similar.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Se cargan los datos de las estrellas de M31
data = pd.read_csv('ejer4')

data
# Out:
#     _RAJ2000  _DEJ2000  RAJ2000  DEJ2000  Rcmag  Icmag  DeltaRc     Per  \
# 0    10.9321   41.1970  10.9321  41.1970  20.48  19.98     0.27   7.459
# 1    10.8469   41.1737  10.8469  41.1737  20.17  19.69     0.15   8.566
# 2    10.8669   41.2320  10.8669  41.2320  20.61  20.28     0.22   8.836
# 3    10.9366   41.2503  10.9366  41.2503  20.28  19.54     0.11   9.160
# 4    10.9721   41.2128  10.9721  41.2128  20.56  20.04     0.19   9.790
# 5    10.8770   41.0601  10.8770  41.0601  20.43  19.76     0.15  10.383
# 6    10.8736   41.2367  10.8736  41.2367  20.42  20.27     0.28  10.500
# 7    10.7500   41.1426  10.7500  41.1426  19.89  19.55     0.17  11.170
# 8    10.8594   41.2004  10.8594  41.2004  20.21  19.60     0.26  13.773
# 9    10.9290   41.1715  10.9290  41.1715  20.77  19.84     0.48  14.420
# 10   10.9255   41.2489  10.9255  41.2489  19.57  18.87     0.16  15.260
# 11   10.9576   41.2227  10.9576  41.2227  20.84  20.08     0.32  15.460
# 12   10.8259   41.1386  10.8259  41.1386  19.82  19.46     0.40  15.760
# 13   10.9049   41.2419  10.9049  41.2419  19.93  19.58     0.22  15.900
# 14   10.9115   41.2396  10.9115  41.2396  20.79  19.91     0.30  15.950
# 15   10.9775   41.2348  10.9775  41.2348  20.28  19.74     0.40  16.380
# 16   10.9069   41.1868  10.9069  41.1868  20.12  19.60     0.39  16.600
# 17   10.9853   41.2176  10.9853  41.2176  19.47  19.09     0.21  17.730
# 18   10.9839   41.2374  10.9839  41.2374  19.83  19.60     0.32  17.830
# 19   10.9526   41.1540  10.9526  41.1540  19.20  18.99     0.35  20.090
# 20   10.8379   41.1514  10.8379  41.1514  19.74  19.31     0.39  21.440
# 21   10.8272   41.1071  10.8272  41.1071  20.01  19.19     0.29  26.990
# 22   10.9059   41.2379  10.9059  41.2379  19.78  18.92     0.34  28.780
# 23   10.9002   41.1823  10.9002  41.1823  20.55  19.57     0.23  35.120
# 24   10.9293   41.2475  10.9293  41.2475  18.89  18.35     0.31  43.530
# 25   10.9183   41.1856  10.9183  41.1856  19.36  18.82     0.22  56.020
#
#     MagnitudAbsoluta_I  Age  \
# 0            -4.523135   75
# 1            -4.701023   69
# 2            -4.740917   68
# 3            -4.787211   67
# 4            -4.872717   64
# 5            -4.948316   62
# 6            -4.962720   61
# 7            -5.042237   59
# 8            -5.311524   52
# 9            -5.370537   51
# 10           -5.443321   49
# 11           -5.460060   49
# 12           -5.484766   48
# 13           -5.496135   48
# 14           -5.500172   48
# 15           -5.534369   47
# 16           -5.551520   47
# 17           -5.636178   45
# 18           -5.643408   45
# 19           -5.796821   42
# 20           -5.880425   40
# 21           -6.176361   35
# 22           -6.258909   33
# 23           -6.514841   30
# 24           -6.790814   26
# 25           -7.115096   22
#
#                                                IcFile  \
# 0   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 1   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 2   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 3   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 4   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 5   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 6   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 7   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 8   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 9   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 10  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 11  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 12  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 13  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 14  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 15  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 16  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 17  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 18  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 19  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 20  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 21  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 22  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 23  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 24  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
# 25  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...
#
#                                                RcFile  Distancia    log(P)
# 0   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   2.593250  0.872681
# 1   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   2.462761  0.932778
# 2   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.291555  0.946256
# 3   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   2.391442  0.961895
# 4   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.131563  0.990783
# 5   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   2.850236  1.016323
# 6   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.628789  1.021189
# 7   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   2.701873  1.048053
# 8   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.129843  1.139029
# 9   http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.591907  1.158965
# 10  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   2.376195  1.183555
# 11  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   4.180513  1.189209
# 12  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.178123  1.197556
# 13  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.376328  1.201397
# 14  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.937784  1.202761
# 15  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.699060  1.214314
# 16  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.495600  1.220108
# 17  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   2.873778  1.248709
# 18  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.646694  1.251151
# 19  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   2.955165  1.302980
# 20  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.558792  1.331225
# 21  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.859134  1.431203
# 22  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.539968  1.459091
# 23  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   5.372616  1.545554
# 24  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   3.478408  1.638789
# 25  http://vizier.idia.ac.za/viz-bin/vizExec/Vgrap...   5.014604  1.748343

# %%
#Se grafica el diagrama P-L

plt.figure(figsize=(15,10))
plt.xlabel(u'log(P) (días)', fontsize=14)
plt.ylabel('Magnitud absoluta en el filtro I', fontsize=14)
plt.gca().invert_yaxis()
plt.scatter(data["log(P)"], data["Icmag"], marker = 'o', c = 'grey')    


m, b = np.polyfit(data["log(P)"], data["Icmag"], 1)

#Ajuste lineal con los datos actuales
plt.plot(data["log(P)"], m*data["log(P)"] + b + 0.5, 'y--', label='_nolegend_')
plt.plot(data["log(P)"], m*data["log(P)"] + b, 'y-')
plt.plot(data["log(P)"], m*data["log(P)"] + b - 0.5, 'y--', label='_nolegend_')

#Ajuste lineal de Joshi et al.(2003)
plt.plot(data["log(P)"],  -2.96*data["log(P)"] + 23.52, 'c--', label='_nolegend_')
plt.plot(data["log(P)"],  -2.96*data["log(P)"] + 23.02, 'c')
plt.plot(data["log(P)"],  -2.96*data["log(P)"] + 22.52, 'c--', label='_nolegend_')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.legend(['Ajuste actual','Ajuste Joshi et al. (2003)','Estrellas'])

plt.savefig('Diagrama P-L.png')

plt.show()

print('Pendiente del ajuste lineal actual ' +str(m))
print('Constante del ajuste lineal actual ' +str(b))
# Out:
# Pendiente del ajuste lineal actual -1.5839971154701704
# Constante del ajuste lineal actual 21.440495433853542
